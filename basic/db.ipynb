# %% [markdown]
# ### 데이터베이스 연동
# - 내장 DB 제공 : sqlite(RDBMS)
# - 외부 DB 사용 가능 : mysql, mongo db
# - 라이브러리 설치 : pymysql

# %%
# !pip install pymysql
# Out:
# Collecting pymysql
#   Downloading pymysql-1.1.2-py3-none-any.whl.metadata (4.3 kB)
# Downloading pymysql-1.1.2-py3-none-any.whl (45 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.2

# %% [markdown]
# #### 연결
# - connect() : db 서버 연동
# - cursor : DB와 연결 후 접근할 수 있는 객체

# %%
import pymysql

# %%
conn = pymysql.connect(host="localhost", user="javadb", password='12345', database='springdb', charset="utf8mb4")

# %% [markdown]
# #### 조회
# - fetchall()
# - fetchone()
# - fetchmany()

# %%
with conn.cursor() as cursor:
    sql = "select * from booktbl"
    cursor.execute(sql)
    rows = cursor.fetchall()
    for row in rows:
        print(row)
# Out:
# (40000, 1, '천인국0', 'A1010100', '파워자바0', '12334')
# (36000, 3, '천인국2', 'A1010102', '파워자바2', None)
# (36000, 4, '천인국3', 'A1010103', '파워자바3', '555528283253')
# (-1, 5, '천인국4', 'A1010104', '파워자바4', '')
# (36000, 6, '천인국5', 'A1010105', '파워자바5', '1234')
# (36000, 8, '천인국7', 'A1010107', '파워자바7', None)
# (36000, 9, '천인국8', 'A1010108', '파워자바8', None)
# (36000, 10, '천인국9', 'A1010109', '파워자바9', None)
# (16000, 11, '정대건', 'B101010', '급류', None)
# (16000, 12, '456', 'B1010101', '123', 'ㅁㄴㅇㅁ')
# (80000, 13, '천인국0', '56795931-d58e-11f0-889b-c85acfa7ce35', '파워자바0', '12334')
# (36000, 14, '천인국2', '56795bb9-d58e-11f0-889b-c85acfa7ce35', '파워자바2', None)
# (36000, 15, '천인국3', '56795c35-d58e-11f0-889b-c85acfa7ce35', '파워자바3', '555528283253')
# (-1, 16, '천인국4', '56795c54-d58e-11f0-889b-c85acfa7ce35', '파워자바4', '')
# (36000, 17, '천인국5', '56795cae-d58e-11f0-889b-c85acfa7ce35', '파워자바5', '1234')
# (36000, 18, '천인국7', '56795cc7-d58e-11f0-889b-c85acfa7ce35', '파워자바7', None)
# (36000, 19, '천인국8', '56795cd7-d58e-11f0-889b-c85acfa7ce35', '파워자바8', None)
# (36000, 20, '천인국9', '56795ce6-d58e-11f0-889b-c85acfa7ce35', '파워자바9', None)
# (16000, 21, '정대건', '56795d3e-d58e-11f0-889b-c85acfa7ce35', '급류', None)
# (16000, 22, '456', '56795d59-d58e-11f0-889b-c85acfa7ce35', '123', 'ㅁㄴㅇㅁ')
# (80000, 28, '천인국0', '9015ca8a-d58e-11f0-889b-c85acfa7ce35', '파워자바0', '12334')
# (36000, 29, '천인국2', '9015caec-d58e-11f0-889b-c85acfa7ce35', '파워자바2', None)
# (36000, 30, '천인국3', '9015cb03-d58e-11f0-889b-c85acfa7ce35', '파워자바3', '555528283253')
# (-1, 31, '천인국4', '9015cb16-d58e-11f0-889b-c85acfa7ce35', '파워자바4', '')
# (36000, 32, '천인국5', '9015cb27-d58e-11f0-889b-c85acfa7ce35', '파워자바5', '1234')
# (36000, 33, '천인국7', '9015cb37-d58e-11f0-889b-c85acfa7ce35', '파워자바7', None)
# (36000, 34, '천인국8', '9015cb45-d58e-11f0-889b-c85acfa7ce35', '파워자바8', None)
# (36000, 35, '천인국9', '9015cb53-d58e-11f0-889b-c85acfa7ce35', '파워자바9', None)
# (16000, 36, '정대건', '9015cb63-d58e-11f0-889b-c85acfa7ce35', '급류', None)
# (16000, 37, '456', '9015cb73-d58e-11f0-889b-c85acfa7ce35', '123', 'ㅁㄴㅇㅁ')
# (80000, 38, '천인국0', '9015cb85-d58e-11f0-889b-c85acfa7ce35', '파워자바0', '12334')
# (36000, 39, '천인국2', '9015cb95-d58e-11f0-889b-c85acfa7ce35', '파워자바2', None)
# (36000, 40, '천인국3', '9015cba4-d58e-11f0-889b-c85acfa7ce35', '파워자바3', '555528283253')
# (-1, 41, '천인국4', '9015cbb0-d58e-11f0-889b-c85acfa7ce35', '파워자바4', '')
# (36000, 42, '천인국5', '9015cbbe-d58e-11f0-889b-c85acfa7ce35', '파워자바5', '1234')
# (36000, 43, '천인국7', '9015cbcc-d58e-11f0-889b-c85acfa7ce35', '파워자바7', None)
# (36000, 44, '천인국8', '9015cbd9-d58e-11f0-889b-c85acfa7ce35', '파워자바8', None)
# (36000, 45, '천인국9', '9015cbe6-d58e-11f0-889b-c85acfa7ce35', '파워자바9', None)
# (16000, 46, '정대건', '9015cbf4-d58e-11f0-889b-c85acfa7ce35', '급류', None)
# (16000, 47, '456', '9015cc01-d58e-11f0-889b-c85acfa7ce35', '123', 'ㅁㄴㅇㅁ')
# (80000, 59, '천인국0', '903a2fec-d58e-11f0-889b-c85acfa7ce35', '파워자바0', '12334')
# (36000, 60, '천인국2', '903a303d-d58e-11f0-889b-c85acfa7ce35', '파워자바2', None)
# (36000, 61, '천인국3', '903a3052-d58e-11f0-889b-c85acfa7ce35', '파워자바3', '555528283253')
# (-1, 62, '천인국4', '903a3062-d58e-11f0-889b-c85acfa7ce35', '파워자바4', '')
# (36000, 63, '천인국5', '903a3071-d58e-11f0-889b-c85acfa7ce35', '파워자바5', '1234')
# (36000, 64, '천인국7', '903a3082-d58e-11f0-889b-c85acfa7ce35', '파워자바7', None)
# (36000, 65, '천인국8', '903a3091-d58e-11f0-889b-c85acfa7ce35', '파워자바8', None)
# (36000, 66, '천인국9', '903a309e-d58e-11f0-889b-c85acfa7ce35', '파워자바9', None)
# (16000, 67, '정대건', '903a30af-d58e-11f0-889b-c85acfa7ce35', '급류', None)
# (16000, 68, '456', '903a30c0-d58e-11f0-889b-c85acfa7ce35', '123', 'ㅁㄴㅇㅁ')
# (80000, 69, '천인국0', '903a30cf-d58e-11f0-889b-c85acfa7ce35', '파워자바0', '12334')
# (36000, 70, '천인국2', '903a30e0-d58e-11f0-889b-c85acfa7ce35', '파워자바2', None)
# (36000, 71, '천인국3', '903a30ed-d58e-11f0-889b-c85acfa7ce35', '파워자바3', '555528283253')
# (-1, 72, '천인국4', '903a30fc-d58e-11f0-889b-c85acfa7ce35', '파워자바4', '')
# (36000, 73, '천인국5', '903a3109-d58e-11f0-889b-c85acfa7ce35', '파워자바5', '1234')
# (36000,
d58e-11f0-889b-c85acfa7ce35', '급류', None)
# (16000, 181, '456', '9caba577-d58e-11f0-889b-c85acfa7ce35', '123', 'ㅁㄴㅇㅁ')
# (80000, 182, '천인국0', '9caba584-d58e-11f0-889b-c85acfa7ce35', '파워자바0', '12334')
# (36000, 183, '천인국2', '9caba591-d58e-11f0-889b-c85acfa7ce35', '파워자바2', None)
# (36000, 184, '천인국3', '9caba59d-d58e-11f0-889b-c85acfa7ce35', '파워자바3', '555528283253')
# (-1, 185, '천인국4', '9caba5aa-d58e-11f0-889b-c85acfa7ce35', '파워자바4', '')
# (36000, 186, '천인국5', '9caba5b6-d58e-11f0-889b-c85acfa7ce35', '파워자바5', '1234')
# (36000, 187, '천인국7', '9caba5c3-d58e-11f0-889b-c85acfa7ce35', '파워자바7', None)
# (36000, 188, '천인국8', '9caba5d0-d58e-11f0-889b-c85acfa7ce35', '파워자바8', None)
# (36000, 189, '천인국9', '9caba5dd-d58e-11f0-889b-c85acfa7ce35', '파워자바9', None)
# (16000, 190, '정대건', '9caba5e8-d58e-11f0-889b-c85acfa7ce35', '급류', None)
# (16000, 191, '456', '9caba5f5-d58e-11f0-889b-c85acfa7ce35', '123', 'ㅁㄴㅇㅁ')
# (80000, 192, '천인국0', '9caba601-d58e-11f0-889b-c85acfa7ce35', '파워자바0', '12334')
# (36000, 193, '천인국2', '9caba60e-d58e-11f0-889b-c85acfa7ce35', '파워자바2', None)
# (36000, 194, '천인국3', '9caba61a-d58e-11f0-889b-c85acfa7ce35', '파워자바3', '555528283253')
# (-1, 195, '천인국4', '9caba627-d58e-11f0-889b-c85acfa7ce35', '파워자바4', '')
# (36000, 196, '천인국5', '9caba633-d58e-11f0-889b-c85acfa7ce35', '파워자바5', '1234')
# (36000, 197, '천인국7', '9caba64a-d58e-11f0-889b-c85acfa7ce35', '파워자바7', None)
# (36000, 198, '천인국8', '9caba656-d58e-11f0-889b-c85acfa7ce35', '파워자바8', None)
# (36000, 199, '천인국9', '9caba662-d58e-11f0-889b-c85acfa7ce35', '파워자바9', None)
# (16000, 200, '정대건', '9caba66f-d58e-11f0-889b-c85acfa7ce35', '급류', None)
# (16000, 201, '456', '9caba67b-d58e-11f0-889b-c85acfa7ce35', '123', 'ㅁㄴㅇㅁ')
# (36000, 249, '천인국', 'A101010', '파워자바', None)
# (123456, 251, '123456', '123456', '123456', '123456')

# %%
with conn.cursor() as cursor:
    sql = "select * from booktbl"
    cursor.execute(sql)
    rows = cursor.fetchmany(size=10)
    for row in rows:
        print(row)
# Out:
# (40000, 1, '천인국0', 'A1010100', '파워자바0', '12334')
# (36000, 3, '천인국2', 'A1010102', '파워자바2', None)
# (36000, 4, '천인국3', 'A1010103', '파워자바3', '555528283253')
# (-1, 5, '천인국4', 'A1010104', '파워자바4', '')
# (36000, 6, '천인국5', 'A1010105', '파워자바5', '1234')
# (36000, 8, '천인국7', 'A1010107', '파워자바7', None)
# (36000, 9, '천인국8', 'A1010108', '파워자바8', None)
# (36000, 10, '천인국9', 'A1010109', '파워자바9', None)
# (16000, 11, '정대건', 'B101010', '급류', None)
# (16000, 12, '456', 'B1010101', '123', 'ㅁㄴㅇㅁ')

# %%
with conn.cursor() as cursor:
    sql = "select * from booktbl"
    cursor.execute(sql)
    rows = cursor.fetchone()
    print(rows)
# Out:
# (40000, 1, '천인국0', 'A1010100', '파워자바0', '12334')

# %% [markdown]
# #### 테이블 생성

# %%
with conn.cursor() as cursor:
    sql = "create table if not exists users(id int primary key auto_increment, name varchar(30), " \
    "email varchar(100), phone varchar(20), website varchar(50), regdate date)"
    cursor.execute(sql)

# %% [markdown]
# #### 삽입

# %%
from datetime import datetime

now = datetime.now()
print(now)
today = now.strftime("%Y-/%m-/%d")
# Out:
# 2026-02-09 16:49:52.446963

# %%
# 데이터 삽입 시 튜플 형태

with conn.cursor() as cursor:
    sql = "insert into users(name, email, phone, website, regdate) values(%s,%s,%s,%s,%s)"
    cursor.execute(sql,('user1', 'user1@gmail.com', '010-1234-1234', 'http://user1.com', today))

conn.commit()

# %%
with conn.cursor() as cursor:
    sql = "select * from users"
    cursor.execute(sql)
    rows = cursor.fetchall()
    for row in rows:
        print(row)
# Out:
# (1, 'user1', 'user1@gmail.com', '010-1234-1234', 'http://user1.com', datetime.date(2026, 2, 9))
# (2, 'change2', 'user2@gmail.com', '010-1234-1234', 'http://user2.com', datetime.date(2026, 2, 9))
# (3, 'user3', 'user3@gmail.com', '010-1234-1234', 'http://user3.com', datetime.date(2026, 2, 9))
# (4, 'user4', 'user4@gmail.com', '010-1234-1234', 'http://user4.com', datetime.date(2026, 2, 9))

# %%
with conn.cursor() as cursor:

    users = (
        ('user2', 'user2@gmail.com', '010-1234-1234', 'http://user2.com', today),
        ('user3', 'user3@gmail.com', '010-1234-1234', 'http://user3.com', today),
        ('user4', 'user4@gmail.com', '010-1234-1234', 'http://user4.com', today),
        ('user5', 'user5@gmail.com', '010-1234-1234', 'http://user5.com', today)
    )

    sql = "insert into users(name, email, phone, website, regdate) values(%s,%s,%s,%s,%s)"
    cursor.executemany(sql, users)

conn.commit()

# %% [markdown]
# ### 조회

# %%
with conn.cursor() as cursor:
    sql = "select * from users where id = 3"
    cursor.execute(sql)
    rows = cursor.fetchall()
    for row in rows:
        print(row)
# Out:
# (3, 'user3', 'user3@gmail.com', '010-1234-1234', 'http://user3.com', datetime.date(2026, 2, 9))

# %%
with conn.cursor() as cursor:
    sql = "select * from users where id = %s"
    cursor.execute(sql, 5)
    rows = cursor.fetchall()
    for row in rows:
        print(row)
# Out:
# (5, 'user5', 'user5@gmail.com', '010-1234-1234', 'http://user5.com', datetime.date(2026, 2, 9))

# %%
with conn.cursor() as cursor:
    sql = "select * from users where id in (%s, %s)"
    cursor.execute(sql, (3,5))
    rows = cursor.fetchall()
    for row in rows:
        print(row)
# Out:
# (3, 'user3', 'user3@gmail.com', '010-1234-1234', 'http://user3.com', datetime.date(2026, 2, 9))
# (5, 'user5', 'user5@gmail.com', '010-1234-1234', 'http://user5.com', datetime.date(2026, 2, 9))

# %% [markdown]
# ### 업데이트

# %%
with conn.cursor() as cursor:
    sql = "update users set name = %s where id = %s"
    cursor.execute(sql, ('change2', 2))

conn.commit()

# %% [markdown]
# #### 삭제

# %%
with conn.cursor() as cursor:
    sql = "delete from users where id = %s"
    cursor.execute(sql, 5)

conn.commit()
