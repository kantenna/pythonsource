# %%
from fake_useragent import UserAgent
import requests
from bs4 import BeautifulSoup
import csv
import pymysql
from pymongo import MongoClient
from bson import ObjectId

# %%
headers = {
    "X-Naver-Client-Id":"OFdbE5DsI58ojgibwm6A",
    "X-Naver-Client-Secret":"J92mx3ownR"
}

url = "https://openapi.naver.com/v1/search/book.json"

start = 1

# csv 저장
books = []
no = 1

# sql 저장용
books_sql = []

# mongo 저장용
books_mongo = []

with requests.Session() as s:

    for idx in range(3):
        start_num = start + (idx * 100)
        
        param = {
            "query": "주식",
            "display": "100",
            "start": start_num
        }

        res = s.get(url, headers=headers, params=param)
        contents = res.json()
        for book in contents["items"]:
            # print(book['title'], book['author'], book['discount'], book['publisher'])
            books.append([no, book['title'], book['author'], book['discount'], book['publisher']])
            books_sql.append([book['title'], book['author'], book['discount'], book['publisher']])
            book_m = {
                "title": book["title"],
                "author": book['author'],
                "discount": book['discount'],
                "publisher": book['publisher']
            }
            books_mongo.append(book_m)
            no += 1

# %%
# books
with open("./data/books.csv","w",newline="", encoding="utf-8") as fw:
    wt = csv.writer(fw)

    for v in books:
        wt.writerow(v)

# %%
# mysql db 저장

conn = pymysql.connect(host="localhost", user="javadb", password='12345', database='springdb', charset="utf8mb4")

with conn.cursor() as cursor:
    sql = "create table if not exists books(id int primary key auto_increment, title varchar(100), " \
    "author varchar(50), discount int, publisher varchar(100))"
    cursor.execute(sql)

# %%
with conn.cursor() as cursor:

    sql = "insert into books(title, author, discount, publisher) values(%s,%s,%s,%s)"
    cursor.executemany(sql, books_sql)

conn.commit()

# %%
# mongodb 연결
client = MongoClient("mongodb+srv://kantenna11_db_user:56Stx6hcxbwU5SJ6@cluster0.kbv7ju2.mongodb.net/")

db = client["test"]

# %%
books_mongo
# Out:
# [{'title': '진보를 위한 주식투자 (광수네 복덕방, 모두의 투자 이야기)',
#   'author': '이광수',
#   'discount': '19800',
#   'publisher': '21세기북스'},
#  {'title': '캔들차트 하나로 끝내는 추세추종 투자 (주식 매수 매도 타이밍을 읽는 눈)',
#   'author': '성승현',
#   'discount': '22500',
#   'publisher': '포르체'},
#  {'title': '텐배거 포트폴리오 (김학주가 짚어주는 시장의 미래를 바꿀 주식 TOP 50)',
#   'author': '김학주',
#   'discount': '19800',
#   'publisher': '페이지2북스'},
#  {'title': '주식투자 무작정 따라하기(2026) (100만 왕초보가 감동한 최고의 주식투자 입문서)',
#   'author': '윤재수',
#   'discount': '22500',
#   'publisher': '길벗'},
#  {'title': '대형주 추세추종 투자법칙 (130만 원으로 20억 만든 주식 실전 매매 전략)',
#   'author': '이종호(전황)',
#   'discount': '19800',
#   'publisher': '사피엔테스'},
#  {'title': '나의 첫 월배당 ETF (돈 걱정 없는 인생을 만드는)',
#   'author': '김정란',
#   'discount': '19800',
#   'publisher': '토네이도'},
#  {'title': 'ETF 투자의 모든 것 (배당수익과 주가수익 다 잡는 제2의 소득 파이프라인)',
#   'author': '문일호',
#   'discount': '18900',
#   'publisher': '매일경제신문사'},
#  {'title': '1,000만 원으로 3년 안에 300만 원 월배당 만들기 (미국 ETF 초간단 인컴 포트폴리오 전략)',
#   'author': '인생업(임승현)',
#   'discount': '20700',
#   'publisher': '경이로움'},
#  {'title': '금융의 연금술 (전 세계 3대 투자 거장 조지 소로스가 남긴 유일한 주식 투자 바이블)',
#   'author': '조지 소로스',
#   'discount': '34200',
#   'publisher': '다산북스'},
#  {'title': '주식 투자의 기쁨 (89세 현역 트레이더 시게루 할아버지의 흔들리지 않는 투자 철학)',
#   'author': '후지모토 시게루',
#   'discount': '17820',
#   'publisher': '다산북스'},
#  {'title': '규칙파괴자 (20년간 45배 수익, 모틀리풀의 시장을 이기는 주식투자)',
#   'author': '데이비드 가드너',
#   'discount': '22500',
#   'publisher': '국일증권경제연구소'},
#  {'title': '주식 고수들만 아는 네이버 증권 200% 활용법(개정판 4판) (네이버 증권으로 배우는 ‘주식투자 실전 가이드북!)',
#   'author': '알렉스 강',
#   'discount': '18000',
#   'publisher': '스마트비즈니스'},
#  {'title': '부자 아빠 투자 불변의 법칙 (500억 자산가가 남긴 마지막 유산)',
#   'author': '타짱',
#   'discount': '18000',
#   'publisher': '큰숲'},
#  {'title': '단 3개의 미국 ETF로 은퇴하라 (원하는 삶을 앞당기는 돈 자동 사냥 시스템)',
#   'author': '김지훈(포메뽀꼬)',
#   'discount': '17820',
#   'publisher': '리더스북'},
#  {'title': '2026 한국에 투자하라 (코스피 1만, 새로운 부의 법칙)',
#   'author': '나탈리 허',
#   'discount': '16650',
#   'publisher': '쌤앤파커스'},
#  {'title': '모든 주식을 소유하라(리커버판)',
#   'author': '존 보글',
#   'discount': '16200',
#   'publisher': '비즈니스맵'},
#  {'title': '인사이더 인사이트 (평생 투자할 당신이 알아야 할 월스트리트 돈의 논리)',
#   'author': '이용준',
#   'discount': '17100',
#   'publisher': '에프엔미디어'},
#  {'title': '가속화 장기투자 법칙 (4000만 원으로 시작해 40억 만든 가치주 배당 혁명)',
#   'author': '임인홍',
#   'discount': '18414',
#   'publisher': '길벗'},
#  {'title': '주식 투자의 뿌리 (두 번의 깡통을 차고 500억을 모으기까지)',
#   'author': '박두환',
#   'discount': '19800',
#   'publisher': '애덤스미스'},
#  {'title': '돈, 뜨겁게 사랑하고 차갑게 다루어라 (22주년 기념 양장 특별판)',
#   'author': '앙드레 코스톨라니',
#   'discount': '16200',
#   'publisher': '미래의창'},
#  {'title': '워런 버핏 바이블: 완결판 (버핏이 직접 말해주는 투자와 경영, 삶의 지혜: 1983~2025)',
#   'author': '워렌 버핏^리처드 코너스',
#   'discount': '34200',
#   'publisher': '에프엔미디어'},
#  {'title': '대신 주식해드립니다 (S대 경제·심리 전공 17년 차 감성 투자자의 손실 방지책)',
#   'author': '이민수',
#   'discount': '16200',
#   'publisher': '알에이치코리아'},
#  {'title': '누구나 투자로 부자가 될 수 있다 (AI 시대, ETF 투자 전략)',
#   'author': '배재규',
#   'discount': '18000',
#   'publisher': '이든하우스'},
#  {'title': '사이클 투자 법칙 (주식시장 슈퍼사이클에 올라타는 실전 매매법)',
#   'author': '조윤남',
#   'discount': '19800',
#   'publisher': '한국경제신문'},
#  {'title': '다모다란의 기업 생애주기 (투자, 사업, 경영을 아우르는 최강의 프레임워크)',
#   'author': '애스워드 다모다란',
#   'discount': '29700',
#   'publisher': '에프엔미디어'},
#  {'title': '손실은 짧게 수익은 길게 (자기만의 손익비를 찾아라!)',
#   'author': '깡토',
#   'discount': '22500',
#   'publisher': '이레미디어'},
#  {'title': '워런 버핏과 찰리 멍거 (세계 최고의 투자 수업)',
#   'author': '워렌 버핏^Munger, Charles T.^알렉스 모리스',
#   'discount': '31500',
#   'publisher': '교보문고'},
#  {'title': '가난한 찰리의 연감 (버크셔 해서웨이의 전설, 찰리 멍거의 모든 것)',
#   'author': 'Munger, Charles T.',
#   'discount': '29700',
#   'publisher': '김영사'},
#  {'title': '투자디톡스 + 필사노트 세트 (본성에 휘둘리지 않고 불안에서 벗어나기)',
#   'author': '문홍철',
#   'discount': '26550',
#   'publisher': '연합인포맥스북스'},
#  {'title': '부의 초가속 (절약, 꾸준한 투자, 시간이 만드는 마법)',
#   'author': '황정호',
#   'discount': '18000',
#   'publisher': '클라우드나인'},
#  {'title': '주린이도 술술 읽는 친절한 ETF (ETF 왕초보가 꼭 알아야 할 기본)',
#   'author': '중앙일보 머니랩',
#   'discount': '16200',
#   'publisher': '메이트북스'},
#  {'title': '처음부터 시작하는 주식투자 단타전략 (15만 원으로 10억 만든 실전투자대회 1위 수상자의 필승 트레이딩 공식)',
#   'author': '홍인기',
#   'discount': '18900',
#   'publisher': '길벗'},
#  {'title': '돈, 뜨겁게 사랑하고 차갑게 다루어라',
#   'author': '앙드레 코스톨라니',
#   'discount': '13500',
#   'publisher': '미래의창'},
#  {'title': '주식투자 단기 트레이딩의 정석 (25년 투자 고수가 전하는 매일 수익 내는 단타 매매의 기술)',
#   'author': '강창권',
#   'discount': '27621',
#   'publisher': '길벗'},
#  {'title': '월가의 영웅 (주식투자에서 상식으로 성공하는 법, 2021 최신개정판)',
#   'author': '피터 린치^존 로스차일드',
#   'discount': '23400',
#   'publisher': '국일증권경제연구소'},
#  {'title': '위대한 기업에 투자하라 (기업의 탁월한 경쟁력은 어떻게 최고의 투자 수익과 연결되는가)',
#   'author': '필립 피셔',
#   'discount': '16200',
#   'publisher': '굿모닝북스'},
#  {'title': '1%를 읽는 힘 (세상의 정보를 연결해서 기회를 포착하는 생각 혁신)',
#   'author': '메르',
#   'discount': '19800',
#   'publisher': '토네이도'},
#  {'title': '미국주식 처음공부 (시작부터 술술 풀리고 바로 써먹는, 개정판)',
#   'author': '수미숨(상의민)^애나정',
#   'discount': '19800',
#   'publisher': '이레미디어'},
#  {'title': '챔피언처럼 생각하고 거래하라 (주식시장의 마법사가 지닌 비밀, 원칙 그리고 있는 그대로의 진실)',
#   'author': '마크 미너비니',
#   'discount': '22500',
#   'publisher': '이레미디어'},
#  {'title': '거인의 어깨 1 (벤저민 그레이엄, 워런 버핏, 피터 린치에게  배우다)',
#   'author': '홍진채',
#   'discount': '18720',
#   'publisher': '포레스트북스'},
#  {'title': '처음 배우는 주식 차트',
#   'author': '한재승',
#   'discount': '34200',
#   'publisher': '알에이치코리아'},
#  {'title': '라오어의 미국주식 무한매수법 (레버리지가 아니면 평범한 인생을 바꿀 수 없다)',
#   'author': '라오어',
#   'discount': '14400',
#   'publisher': '알키'},
#  {'title': '차트분석 무작정 따라하기 (100만 독자가 인정한 주식 1등 저자의 책)',
#   'author': '윤재수',
#   'discount': '22500',
#   'publisher': '길벗'},
#  {'title': '워런 버핏의 주주 서한 (버핏이 인정한 유일한 버핏 책, 제6판 개정증보판)',
#   'author': '워렌 버핏^로렌스 커닝햄',
#   'discount': '28800',
#   'publisher': '에프엔미디어'},
#  {'title': '절대수익 우량주 매매법 (주식투자 수익은 하나의 패턴이면 충분하다!)',
#   'author': '성경호',
#   'discount': '35100',
#   'publisher': '이레미디어'},
#  {'title': '코스피 1만 넥스트 레벨 (전 국민 주주 시대, 박시동의 실전 투자 비법)',
#   'author': '박시동',
#   'discount': '19800',
#   'publisher': '지와인'},
#  {'title': '최고의 주식 최적의 타이밍 (개정판, 윌리엄 오닐의 실전 투자 전략)',
#   'author': '윌리엄 J. 오닐',
#   'discount': '17820',
#   'publisher': '굿모닝북스'},
#  {'title': '투자의 배신 (월가의 전설 켄 피셔가 폭로하는 주식시장의 거짓말)',
#   'author': '켄 피셔^라라 호프만스',
#   'discount': '17820',
#   'publisher': '길벗'},
#  {'title': '주식시장은 어떻게 반복되는가 (역사에서 배우는 켄 피셔의 백전불태 투자 전략)',
#   'author': '켄 피셔^라라 호프만스',
#   'discount': '16200',
#   'publisher': '에프엔미디어'},
#  {'title': '투자에 대한 생각 (월스트리트가 가장 신뢰한 하워드 막스의 20가지 투자 철학)',
#   'author': '하워드 막스',
#   'discount': '13500',
#   'publisher': '비즈니스맵'},
#  {'title': '주식하는 마음 (주식투자의 운과 실력, 결국은 마음이다!)',
#   'author': '홍진채',
#   'discount': '19800',
#   'publisher': '다산북스'},
#  {'title': '트레이딩의 전설 (실전투자대회 수상자 9인을 만나다)',
#   'author': '키움증권 채널K',
#   'discount': '15300',
#   'publisher': '넥스트씨'},
#  {'title': '보글헤드 쓰리펀드 포트폴리오 (단 3개의 ETF로 충분하다!)',
#   'author': '테일러 래리모어',
#   'discount': '16200',
#   'publisher': '빈티지하우스'},
#  {'title': '인생을 바꾸는 최고의 ETF (괜찮은 ETF 투자하고, 나가서 운동합니다)',
#   'author': '잼투리',
#   'discount': '22050',
#   'publisher': '거인의정원'},
#  {'title': 'ETF 첫걸음 (주식보다 똑똑한 투자의 정답)',
#   'author': '조진우(CFA)^김성천(Ph.D.)',
#   'discount': '20700',
#   'publisher': '한스미디어'},
#  {'title': '빅 트레이더의 주도주 매매법 (지금 가장 뜨거운 종목에 투자하라!)',
#   'author': '서희파더(이재상)',
#   'discount': '28350',
#   'publisher': '이레미디어'},
#  {'title': '투자는 심리게임이다(25주년 특별 기념판) (’코스톨라니의 말’ 30일 필사 노트 특별 수록)',
#   'author': '앙드레 코스톨라니',
#   'discount': '16200',
#   'publisher': '미래의창'},
#  {'title': '피터 린치의 투자 이야기(큰글자책) (월가의 영웅, 피터 린치의 개인 투자자를 위한 주식·펀드 투자)',
#   'author': '피터 린치^존 로스차일드',
#   'discount': '37800',
#   'publisher': '흐름출판'},
#  {'title': '초보자를 단숨에 고수로 만드는 주식투자 핵심 수업 (슈퍼개미 이세무사 따라 텐베거 잡기)',
#   'author': '이정윤',
#   'discount': '22500',
#   'publisher': '이레미디어'},
#  {'title': '주린이도 술술 읽는 친절한 주식책 (완전 개정증보판)',
#   'author': '최정희^이슬기',
#   'discount': '16200',
#   'publisher': '메이트북스'},
#  {'title': '해외선물 처음공부 (단돈 100만 원으로 달러, 금, 오일, 나스닥선물을 시작할 수 있는)',
#   'author': '김직선',
#   'discount': '22500',
#   'publisher': '이레미디어'},
#  {'title': '내 월급을 자산으로 바꾸는 ETF 투자의 기술 (내 월급을 자산으로 바꾸는)',
#   'author': '최창윤',
#   'discount': '18000',
#   'publisher': '원앤원북스'},
#  {'title': '퀀트 투자의 기초 (펀더멘털 투자자를 위한 퀀트 가이드)',
#   'author': '지우세페 팔레올로고',
#   'discount': '22320',
#   'publisher': '비지니스101'},
#  {'title': '거인의 어깨 위에서 올바르게 투자하라 (어디서나 통하는 초수익 투자법부터 작전주 함정 분석까지)',
#   'author': '올투(올바른 투자)',
#   'discount': '22050',
#   'publisher': '동양북스'},
#  {'title': '플스포의 메타인지 투자법 (잃지 않는 초수익 투자의 모든 것)',
#   'author': '플스포(김동호)',
#   'discount': '19800',
#   'publisher': '한국경제신문'},
#  {'title': '주도주 투자 수익의 정석 (20년간 연간소실 0원, 국가대표 프랍 트레이더의 완벽한 ’손익비’ 전략)',
#   'author': '김진',
#   'discount': '18900',
#   'publisher': '체인지업'},
#  {'title': '미국주식 슈퍼 2등 전쟁 (폭발적 수익을 끌어내는 미국 주식 투자 전략)',
#   'author': '윤진호^신년기',
#   'discount': '19800',
#   'publisher': '타인의취향'},
#  {'title': '한 권으로 끝내는 미국 ETF 투자 (처음부터 제대로 배우는 미국 ETF 투자 공식)',
#   'author': '이을수',
#   'discount': '20700',
#   'publisher': '한국경제신문'},
#  {'title': '데이 스윙 트레이딩 바이블 (스윙 트레이딩’ 창안자의 실전 도구와 기법)',
#   'author': '올리버 벨레즈^그렉 캐프라',
#   'discount': '24300',
#   'publisher': '이레미디어'},
#  {'title': '피터 린치의 이기는 투자(큰글자책) (월가의 영웅, 피터 린치의 개인 투자자를 위한 주식·펀드 투자)',
#   'author': '피터 린치^존 로스차일드',
#   'discount': '43200',
#   'publisher': '흐름출판'},
#  {'title': '금융시장의 기술적 분석',
#   'author': '존 J.머피',
#   'discount': '35154',
#   'publisher': '국일증권경제연구소'},
#  {'title': '3분봉 매매의 기술 (’상대적 저가’에서 매수해 확실하게 수익내는)',
#   'author': '오버솔드',
#   'discount': '26100',
#   'publisher': '원앤원북스'},
#  {'title': '개미 목사의 주식투자 첫걸음 (누구나 따라 하는 크리스천 금융문맹 탈출 대작전)',
#   'author': '장일',
#   'discount': '16200',
#   'publisher': '사자와어린양'},
#  {'title': '[그래제본소] 벤저민 그레이엄의 증권분석 (개정 제7판)',
#   'author': '벤저민 그레이엄^데이비드 도드',
#   'discount': '41013',
#   'publisher': '비즈니스북스'},
#  {'title': '한국의 미래 (거대한 변곡점, 마지막 부의 기회를 잡아라)',
#   'author': '박석중',
#   'discount': '19800',
#   'publisher': '페이지2북스'},
#  {'title': '실전 투자강의 (22주년 기념 양장 특별판)',
#   'author': '앙드레 코스톨라니',
#   'discount': '15300',
#   'publisher': '미래의창'},
#  {'title': '거버넌스 트렌드 인사이트 2026 (숫자보다 중요한 구조의 변화)',
#   'author': '천준범',
#   'discount': '17100',
#   'publisher': '이스터에그'},
#  {'title': '오늘 시작해도 늦지 않은 주식 공부',
#   'author': '곽유정',
#   'discount': '18000',
#   'publisher': '원앤원북스'},
#  {'title': '언제 매도할 것인가 (이익매도, 손절매도, 공매도, 선물매도 알렉산더 엘더가 알려주는 매도의 모든 것)',
#   'author': '알렉산더 엘더',
#   'discount': '24300',
#   'publisher': '이레미디어'},
#  {'title': '주식시장을 이기는 작은 책 (어떤 시장에서도 흔들리지 않는  마법의 투자 공식)',
#   'author': '조엘 그린블라트',
#   'discount': '19800',
#   'publisher': '다산북스'},
#  {'title': '장우석의 미국주식 투자법 (대한민국 No.1 미국주식 멘토’ 미주미’)',
#   'author': '장우석^김준형',
#   'discount': '22599',
#   'publisher': '베가북스'},
#  {'title': '월급이 평생 오르는 미국 배당주에 투자하라 (무한계단처럼 제2의 소득이 쌓이는 기적의 월배당 시스템)',
#   'author': '이의석',
#   'discount': '21600',
#   'publisher': '알에이치코리아'},
#  {'title': '내 주식에게 일어날 수 있는 모든 일 (주식 투자 하기 전에 가장 먼저 알아야 할 것들)',
#   'author': '선진호',
#   'discount': '16200',
#   'publisher': '올드스테어즈'},
#  {'title': '미국주식 어떤 기업에 투자할 것인가 (앞으로 10년을 이끌어갈 히든 챔피언을 찾아라!)',
#   'author': '고은미',
#   'discount': '19800',
#   'publisher': '토네이도'},
#  {'title': '워런 버핏의 2단계 주식투자 전략 (처음 만나는 가치투자 교과서)',
#   'author': 'Jiwani, Danial',
#   'discount': '17010',
#   'publisher': '동아엠앤비'},
#  {'title': '실전 증권사관학교 X파일 (종목 발굴 이렇게 하라!)',
#   'author': '장진영',
#   'discount': '22500',
#   'publisher': '이레미디어'},
#  {'title': '주도섹터 돌파매매 전략 (전미투자대회 우승자들의 핵심 매매 기법 2)',
#   'author': '김대현',
#   'discount': '23220',
#   'publisher': '이레미디어'},
#  {'title': '투자의 기술 (글로벌 IB 7개사에서 30년 동안 투자 경험을 축적한 트레이더 김준승)',
#   'author': '김준송',
#   'discount': '19350',
#   'publisher': '연합인포맥스북스'},
#  {'title': '주식투자의 9할은 심리 싸움이다 (투자 심리로 해부한 ‘주식투자의 본성!’)',
#   'author': '리처드 L. 피터슨',
#   'discount': '22500',
#   'publisher': '스마트비즈니스'},
#  {'title': '나는 미국 월배당 ETF로 40대에 은퇴한다 (7천만 원으로 월 2백만 원 받는 연 30% 이상 초고배당의 비밀)',
#   'author': '최영민',
#   'discount': '16920',
#   'publisher': '지음미디어'},
#  {'title': '실패를 성공으로 바꾸는 주식투자의 기술(불장에디션) (초보 투자자를 위한 부자아빠의 핵심 트레이닝)',
#   'author': '정재호',
#   'discount': '18900',
#   'publisher': '프런트페이지'},
#  {'title': '추세 추종 트레이딩 비법 (세상에서 가장 안전하게 매일 1% 수익 내는)',
#   'author': 'Richard Kwon',
#   'discount': '22500',
#   'publisher': '두드림미디어'},
#  {'title': '한 번 배우면 평생 써먹는 ETF 투자법 (수익에 필요한 것만 배우고 바로 시작하자)',
#   'author': '윤타(윤영준)',
#   'discount': '18900',
#   'publisher': '동양북스'},
#  {'title': '나만의 투자 루틴을 완성하는 미주부 주식 투자 수업 (데이터와 시스템으로 사고하는 미주부 템플릿 200% 활용법)',
#   'author': '김훈',
#   'discount': '18000',
#   'publisher': '이든하우스'},
#  {'title': '1%를 읽는 매크로 투자 주식의 코드 (1%를 읽는 매크로 투자)',
#   'author': '주식의 코드',
#   'discount': '21600',
#   'publisher': '베가북스'},
#  {'title': '윌리엄 오닐의 공매도 투자 기법(리커버) (최적의 매도 타이밍에 관한 모든 것)',
#   'author': '윌리엄 J. 오닐^길 모랄레스',
#   'discount': '18900',
#   'publisher': '이레미디어'},
#  {'title': 'AI 로봇 반도체 BIG 3 투자 트렌드 (트렌드에 숨겨진 비즈니스와 투자의 해답)',
#   'author': '최중혁^이상진^최민규^허진^서민교',
#   'discount': '22500',
#   'publisher': '한스미디어'},
#  {'title': '워너비 투자자 (첫 주식을 사기 전에 반드시 알아야 할 투자 레슨 40)',
#   'author': '앤 마리 사바스',
#   'discount': '19350',
#   'publisher': '동양북스'},
#  {'title': '미국 주식 투자 (2030~40년에도 성장이 멈추지 않는다)',
#   'author': '오카모토 헤이하치로',
#   'discount': '16200',
#   'publisher': '지상사'},
#  {'title': 'ETF 투자의 모든 것(큰글자도서) (당수익과 주가수익 다 잡는 제2의 소득 파이프라인)',
#   'author': '문일호',
#   'discount': '37830',
#   'publisher': '매일경제신문사'},
#  {'title': '한국 주식 5차 파동 (김대중, 노무현, 이명박, 문재인, 그리고 이재명까지 투자자가 기억해야 할 한국증시의 반복된 역사들)',
#   'author': '효라클(김성효)',
#   'discount': '16200',
#   'publisher': '잇콘'},
#  {'title': '초보자를 위한 투자의 정석(큰글자도서) (우석이 알려주는 실패하지 않는 주식투자법)',
#   'author': '브라운스톤(우석)',
#   'discount': '32980',
#   'publisher': '토트'},
#  {'title': '챗GPT 주식투자 사용설명서 (실전ㆍ실습ㆍ실무에서 바로 써먹는 금융 프롬프트 67)',
#   'author': '황인환^허반석',
#   'discount': '16200',
#   'publisher': '여의도책방'},
#  {'title': '트레이딩은 트레이닝이다 이론 편 (종목 선정부터 매수, 매도까지, 반복 가능한 트레이딩 훈련법)',
#   'author': '장영한^조우태',
#   'discount': '45000',
#   'publisher': '두드림미디어'},
#  {'title': 'AI 시대, 챗GPT는 쓰지만 엔비디아는 놓쳤습니다 (미국 주식부터 ETF, 비트코인까지, 월급으로 시작하는 5단계 투자 로드맵)',
#   'author': '백승호',
#   'discount': '17820',
#   'publisher': '북아지트'},
#  {'title': '혼돈 속의 혼돈(큰글자도서) (1688, 세계 최초의 주식투자 설명서!)',
#   'author': '조셉 드 라 베가',
#   'discount': '32980',
#   'publisher': '스마트비즈니스'},
#  {'title': '패시브 투자의 최종 승자 ETF (독일 최고 금융채널 피난츠플루스 토마스 켈의 안전한 패시브 전략)',
#   'author': '토마스 켈^모나 린케',
#   'discount': '19800',
#   'publisher': '나무생각'},
#  {'title': '배당성장주 투자 불변의 법칙 (평생 월급 1,000만 원 받는 배당투자 시크릿)',
#   'author': '현영준(한라산불곰)',
#   'discount': '17820',
#   'publisher': '체인지업'},
#  {'title': '2025 상장기업 업종 지도 (주식 투자자를 위한 종목 발굴 내비게이션)',
#   'author': '박찬일',
#   'discount': '20700',
#   'publisher': '에프엔미디어'},
#  {'title': '읽으면 돈이 되는 반도체주 투자지도',
#   'author': '곽유정',
#   'discount': '16200',
#   'publisher': '메이트북스'},
#  {'title': '호모 겜블러 (Homo Gambler)',
#   'author': '이시선',
#   'discount': '15000',
#   'publisher': '부크크(bookk)'},
#  {'title': '실패를 성공으로 바꾸는 주식투자의 기술(큰글자도서) (초보 투자자를 위한 부자아빠의 핵심 트레이닝)',
#   'author': '정재호',
#   'discount': '35890',
#   'publisher': '프런트페이지'},
#  {'title': '버튼만 누르면 수익이 돌아간다',
#   'author': '김정수',
#   'discount': '23400',
#   'publisher': '하움출판사'},
#  {'title': '대한민국 투자자를 위한 미국 주식 불패 공식 (현직 해외 주식 전문 PB 연수르의 실전 투자 생중계)',
#   'author': '김연수',
#   'discount': '21600',
#   'publisher': '비즈니스북스'},
#  {'title': '캔들차트 사용설명서 (거래의 신이 전수하는 매매의 기술)',
#   'author': '오자와 미노루',
#   'discount': '18000',
#   'publisher': '여의도책방'},
#  {'title': '주식시장 바로미터',
#   'author': '윌리엄 피터 해밀턴',
#   'discount': '15120',
#   'publisher': '굿모닝북스'},
#  {'title': '최고의 주식 퀄리티 투자 (세계 최고 기업에 투자해 돈을 불리는 가장 확실한 방법)',
#   'author': '뤽 크루제',
#   'discount': '22500',
#   'publisher': '부크온'},
#  {'title': '이동 평균선 투자법 (차트 분석의 시작과 끝은 이동 평균선이다)',
#   'author': '고지로 강사',
#   'discount': '15300',
#   'publisher': '이레미디어'},
#  {'title': '마흔부터는 연금 공부 (평생을 설계하는 액티브 ETF 운용의 기술)',
#   'author': '김호균^도현수',
#   'discount': '19800',
#   'publisher': '한스미디어'},
#  {'title': '빠르게 읽고 바로 활용하는 전자공시 (위치로 읽는 전자공시 활용법)',
#   'author': '김종혁',
#   'discount': '18000',
#   'publisher': '북오션'},
#  {'title': 'IT 산업 트렌드 (AI, 테크부터 뉴스페이스까지, 미래를 선도하는 8가지 투자 로드맵)',
#   'author': '이임복',
#   'discount': '18000',
#   'publisher': '천그루숲'},
#  {'title': '미국 주식 급등주 발굴법 (차트 활용으로 대박이 보이는)',
#   'author': '유지윤(터틀캠프)',
#   'discount': '22500',
#   'publisher': '북오션'},
#  {'title': 'IT 산업 트렌드(큰글자책) (AI, 테크부터 뉴스페이스까지, 미래를 선도하는 8가지 투자 로드맵)',
#   'author': '이임복',
#   'discount': '43200',
#   'publisher': '천그루숲'},
#  {'title': '이웃집 워런 버핏, 숙향의 주식 투자 이야기(특별판) (한층 더 진화해 돌아온 투자 고수, 숙향이 안내하는 경제적 자유의 길)',
#   'author': '숙향',
#   'discount': '20700',
#   'publisher': '한스미디어'},
#  {'title': '글로벌 주식 투자 빅 시프트 (핵심 산업 밸류체인 판이 바뀐다)',
#   'author': '메리츠증권 리서치센터',
#   'discount': '27621',
#   'publisher': '에프엔미디어'},
#  {'title': '이승조의  4등분 주식 매매법 (4등분 법칙, 이것만 알면 노후 걱정 필요없다)',
#   'author': '이승조',
#   'discount': '28800',
#   'publisher': '메이트북스'},
#  {'title': '개미대학 세력의 매집원가 구하기 완결판 (완결판)',
#   'author': '전석',
#   'discount': '18000',
#   'publisher': '오베이북스'},
#  {'title': '월 50만 원으로 8억 만드는 배당머신 (평생 든든한 배당주 월급 부자)',
#   'author': '평온^김지형',
#   'discount': '17100',
#   'publisher': '이나우스북스'},
#  {'title': '시장을 이긴 주식 대가의 성공 투자 비결 (주식 투자로 부자가 되고 싶은 여러분을 위한 주식 고수의 길라잡이)',
#   'author': '이한득',
#   'discount': '17100',
#   'publisher': '좋은땅'},
#  {'title': '보수적인 투자자는 마음이 편하다',
#   'author': '필립 피셔',
#   'discount': '13320',
#   'publisher': '굿모닝북스'},
#  {'title': '트레이딩의 전설(큰글자도서) (실전투자대회 수상자 9인을 만나다)',
#   'author': '키움증권 채널K',
#   'discount': '38800',
#   'publisher': '넥스트씨'},
#  {'title': '데이트레이딩을 알면 주식 시장이 보인다',
#   'author': '니카이도 시게토',
#   'discount': '16920',
#   'publisher': '두드림미디어'},
#  {'title': '주식 거인들에게 배우는 잃지 않는 투자 원칙 49(큰글자도서) (주식 대가들의 ‘원금보전 투자 철학’을 배운다!)',
#   'author': '김명환',
#   'discount': '38800',
#   'publisher': '스마트비즈니스'},
#  {'title': '5000포인트 시대를 위한 투자 대전환 (불확실한 시장을 꿰뚫는 통찰)',
#   'author': '김학균',
#   'discount': '19800',
#   'publisher': '어바웃어북'},
#  {'title': '제임스 몬티어의 가치투자 나침반 (100년의 시간이 증명한 ‘성공 투자 북극성!’)',
#   'author': '제임스 몬티어',
#   'discount': '25200',
#   'publisher': '스마트비즈니스'},
#  {'title': '미국 주식이 답이다 2026 (차근차근 부자 되는 미국 주식투자 입문서)',
#   'author': '장우석^이항영',
#   'discount': '23400',
#   'publisher': '페이지2북스'},
#  {'title': '나는 월급쟁이 배당 부자가 되었다 (배당투자로 월 300만 원 제2의 월급 만드는 시스템)',
#   'author': '환상감자(이은호)',
#   'discount': '19800',
#   'publisher': '길벗'},
#  {'title': '박순혁의 K-주식 투자 바이블 (배터리 아저씨만의 10루타 주식 발견 노하우)',
#   'author': '박순혁',
#   'discount': '24300',
#   'publisher': '애덤스미스'},
#  {'title': '미국주식으로 만드는 두 번째 월급통장',
#   'author': '최만수^선한결^맹진규',
#   'discount': '15300',
#   'publisher': '메이트북스'},
#  {'title': '수익률 높이는 종목 선택법 (사야할 주식, 피해야 할 주식)',
#   'author': '효라클(김성효)',
#   'discount': '19800',
#   'publisher': '황금부엉이'},
#  {'title': '나는 미국 ETF로 해외여행 간다 (초보자를 위한 친절하고 안전한 미국 ETF 교과서)',
#   'author': '유지윤(터틀캠프)',
#   'discount': '18000',
#   'publisher': '북오션'},
#  {'title': '원칙으로 수익 내는 단타의 기술 (상위 1% 주식 트레이더가 지킨 단 하나의 투자 비법)',
#   'author': '원정연(만쥬)',
#   'discount': '19800',
#   'publisher': '길벗'},
#  {'title': '투자는 심리게임이다 (코스톨라니의 투자카페, ’증권심리학’ 강의편)',
#   'author': '앙드레 코스톨라니',
#   'discount': '13440',
#   'publisher': '미래의창'},
#  {'title': '초보도 수익나는 주식차트 심리분석 보는 법 (차트에 숨겨진 비밀을 알려주는 주식책)',
#   'author': '박영수^정동술',
#   'discount': '17100',
#   'publisher': '율도국'},
#  {'title': '미국주식 곡소리날때 매수하라',
#   'author': '박지영',
#   'discount': '17000',
#   'publisher': '부크크(bookk)'},
#  {'title': '고정수익증권론 (제2판)',
#   'author': '윤평식',
#   'discount': '38700',
#   'publisher': '탐진출판사'},
#  {'title': '스타벅스 주식은 1월에 사라 (100만 원으로 시작하는 10년 연속 이벤트 투자 성공의 법칙)',
#   'author': '유나기',
#   'discount': '18000',
#   'publisher': '여의도책방'},
#  {'title': '주식쌩초보 엔비디아, 팔란티어로 2,100% 수익낸 투자여정기',
#   'author': '김은유',
#   'discount': '16200',
#   'publisher': '파워에셋'},
#  {'title': '매직 스플릿 (자산과 현금흐름이 동시에 불어나는 새로운 투자 시스템)',
#   'author': '박성현',
#   'discount': '15300',
#   'publisher': '경이로움'},
#  {'title': '마인드셋은 어떻게 투자의 무기가 되는가 (초수익을 만드는 사고방식의 비밀)',
#   'author': '마크 미너비니',
#   'discount': '18900',
#   'publisher': '이레미디어'},
#  {'title': '사모펀드 해설 (제4판)',
#   'author': '박삼철^차태진^김건^이화석',
#   'discount': '63000',
#   'publisher': '지원출판사'},
#  {'title': '최소한의 투자 공부 (인플레이션, 재무제표, 금리와 투자 원칙까지 주식 투자가 쉬워지는 돈의 기본)',
#   'author': '고토 다쓰야',
#   'discount': '17820',
#   'publisher': '알에이치코리아'},
#  {'title': '기술 성장주에 투자하는 습관 (앞으로 10년을 책임질 인공지능·휴머노이드· 양자컴퓨팅)',
#   'author': '곽재혁',
#   'discount': '18900',
#   'publisher': '좋은습관연구소'},
#  {'title': '월가의 전설 100년 주식투자 비법 (데이비스 투자 가문에게 배우는 주식 불변의 법칙)',
#   'author': '존 로스차일드',
#   'discount': '24300',
#   'publisher': '유노북스'},
#  {'title': '투자은행 사모펀드 핵심개념 101',
#   'author': '안재형',
#   'discount': '22500',
#   'publisher': '지식과감성'},
#  {'title': '알고사자, 비트코인! - 이더리움과 비트코인, 암호화폐와 스테이블코인',
#   'author': '윤부자',
#   'discount': '16800',
#   'publisher': '부크크(bookk)'},
#  {'title': '월가의 늑대 시장을 이겨라 (월가를 뒤흔든 주식 천재의 필승 투자 전략)',
#   'author': '조던 벨포트',
#   'discount': '21600',
#   'publisher': '한국경제신문'},
#  {'title': '진짜 하루만에 이해하는 해운·조선 산업 (조선업 슈퍼 사이클! 놓치면 10년 후회합니다)',
#   'author': '김성훈^엄성희',
#   'discount': '22320',
#   'publisher': '티더블유아이지'},
#  {'title': 'AI 텐베거 투자 (뉴사이클에 진입한 AI 혁명 산업, 10배 종목 발굴을 위한 전략서)',
#   'author': '이형수',
#   'discount': '35010',
#   'publisher': '지베르니'},
#  {'title': '탑다운 퀄리티 투자 (세상의 변화를 미리 읽고 1%에 집중하는 힘)',
#   'author': 'FundEasy',
#   'discount': '16650',
#   'publisher': '지음미디어'},
#  {'title': '채권투자노트',
#   'author': '김형호',
#   'discount': '19800',
#   'publisher': '이패스코리아'},
#  {'title': '스윙투자 전략서 (태쏘의 주식 실전투자)',
#   'author': '태쏘',
#   'discount': '31500',
#   'publisher': '가이아의어깨'},
#  {'title': 'AI시대, 다시 시작하는 반도체 공부 (미세화 한계에서 인공지능 등장까지, 위기를 넘어 진화하는 반도체 기술들)',
#   'author': '정인성',
#   'discount': '20700',
#   'publisher': '애플씨드'},
#  {'title': '알고사자, 미국채권! - 입문편',
#   'author': '윤부자',
#   'discount': '13800',
#   'publisher': '부크크(bookk)'},
#  {'title': '주식 투자 뉴메릭 이론 #39 10배 주식 진행 공식',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': 'ETF 투자 7일 완성 (투자로 부자 되는 가장 쉬운 방법)',
#   'author': '신성호',
#   'discount': '18000',
#   'publisher': '한국경제신문'},
#  {'title': '주식투자 필독서 40 (가치 투자부터 인덱스 펀드까지, 세계 주식 명저 40권을 한 권에)',
#   'author': '차영주',
#   'discount': '18900',
#   'publisher': '센시오'},
#  {'title': '메타 트렌더는 아무도 모를 때 100배 주식을 산다',
#   'author': '나카지마 사토시',
#   'discount': '19800',
#   'publisher': '영림카디널'},
#  {'title': '주식 투자 뉴메릭 이론 #38 Trend Movement',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '배당투자 처음공부 (퇴근 후 1분 투자로 제2의 월급이 따박따박 들어오는)',
#   'author': '이상규',
#   'discount': '19800',
#   'publisher': '이레미디어'},
#  {'title': '주식 투자 뉴메릭 이론 #37 Time Energy Conversion',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': 'BOOKK(부크크)'},
#  {'title': '완벽한 종목 추천 (종목 발굴부터 피칭까지 월가의 실전 투자 수업)',
#   'author': '폴 손킨^폴 존슨',
#   'discount': '22500',
#   'publisher': '에프엔미디어'},
#  {'title': '물어보기 부끄러워 묻지 못한 주식상식 (주식의 기초 개념부터 실제 사고파는 방법까지 누구나 이해하기 쉬운 주식상식 A to Z)',
#   'author': '손환락',
#   'discount': '20700',
#   'publisher': '새로운제안'},
#  {'title': '증권시장론',
#   'author': '김영빈^정호일',
#   'discount': '26600',
#   'publisher': '신영사'},
#  {'title': '재테크농부의 올라운드 투자 (수익을 최대화하는 리밸런싱 전략)',
#   'author': '재테크농부',
#   'discount': '20700',
#   'publisher': '한국경제신문'},
#  {'title': '1만 포인트시대 코스피200 선물옵션주가지수 비트코인 최고수익률 전략',
#   'author': '김정수',
#   'discount': '25800',
#   'publisher': '글로벌'},
#  {'title': '월급처럼 들어오는 미국 배당 투자 (커버드콜, 배당 성장주, 월배당 ETF로 매달 수익 만드는 전략)',
#   'author': '네이르',
#   'discount': '19800',
#   'publisher': '밥북'},
#  {'title': '월배당 ETF 재무제표 완전정복 (85가지 월배당 ETF를 조합해 나만의 배당 포트폴리오를 만드세요!)',
#   'author': '고은미',
#   'discount': '24120',
#   'publisher': '티더블유아이지'},
#  {'title': '한국 주식 슈퍼사이클 (지금, 한국을 사야 하는 결정적 이유)',
#   'author': '신동국',
#   'discount': '18900',
#   'publisher': '매일경제신문사'},
#  {'title': '미국 주식 투자의 정석 (6,000만 뷰 유튜버 ‘미주은’의 투자 교과서)',
#   'author': '최철',
#   'discount': '26100',
#   'publisher': '황금부엉이'},
#  {'title': '전략적 가치투자 (투자에 왕도는 없으나 전략은 있다)',
#   'author': '신진오^이상민',
#   'discount': '20700',
#   'publisher': '국일증권경제연구소'},
#  {'title': '주식 투자 뉴메릭 이론 #36 Time Movement',
#   'author': '손태건',
#   'discount': '15520',
#   'publisher': '부크크(bookk)'},
#  {'title': '주식 투자 뉴메릭 이론 #35 Energy Movement',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '파생상품으로 완성하는 고수의 투자법 (선물·옵션·파생펀드까지 한 권에 담은 실전 투자 가이드)',
#   'author': '최창규',
#   'discount': '19800',
#   'publisher': '위너스북'},
#  {'title': '허영만의 주식 타짜 ― 슈퍼개미 이세무사',
#   'author': '허영만',
#   'discount': '15120',
#   'publisher': '가디언'},
#  {'title': '주식 투자에 대한 생각 (세무사가 기록한 진짜 주식 투자 잘 하는 법)',
#   'author': '김진산',
#   'discount': '18900',
#   'publisher': '페스트북'},
#  {'title': '소액으로 시작하는 예측 가능한 부동산 투자',
#   'author': '퍼스트 클래스',
#   'discount': '25930',
#   'publisher': '더급매'},
#  {'title': '아들아, 미국주식 이렇게 하지 마라 (이야기로 배우는 미국주식 대가의 탄탄한 투자 지혜서)',
#   'author': '이주택',
#   'discount': '16200',
#   'publisher': '위너스북'},
#  {'title': '미국 주식의 절대 법칙 (과거의 주가로 미래의 타이밍을 잡는다)',
#   'author': '박종식',
#   'discount': '23436',
#   'publisher': '북오션'},
#  {'title': '동학개미 주식선물 옵션은 서학개미를 추월한다 (주식선물부터 시작하라!)',
#   'author': 'OX경제연구소',
#   'discount': '20700',
#   'publisher': '글로벌'},
#  {'title': '주식 투자 뉴메릭 이론 #34 Time Ratio Conversion',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '주식 투자 뉴메릭 이론 #33 Time Golden Ratio',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '투자의 전설 앤서니 볼턴 (시류에 거슬러 투자하라!)',
#   'author': '앤서니 볼턴',
#   'discount': '19800',
#   'publisher': '부크온'},
#  {'title': '무조건 이기는 탑다운 주식투자 (이기는 트레이더들의 사고방식과 매매 원칙)',
#   'author': '29PER',
#   'discount': '29700',
#   'publisher': '베가북스'},
#  {'title': '켄 피셔 불변의 차트 90 (극심한 변동성에도 살아남는 대가의 투자법)',
#   'author': '켄 피셔',
#   'discount': '27000',
#   'publisher': '한국경제신문'},
#  {'title': '차이나 디퍼런트 (변하는 중국, 달라질 투자)',
#   'author': '신형관',
#   'discount': '22500',
#   'publisher': '경이로움'},
#  {'title': '주식 투자 뉴메릭 이론 #29 Energy Symmetry',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '추세에 관한 6가지 트레이딩 시스템 (상대강도지수(RSI) 창시자 와일더가 직접 쓴 8가지 투자 기법)',
#   'author': '웰스 와일더',
#   'discount': '20700',
#   'publisher': '이레미디어'},
#  {'title': '주식 투자의 기쁨(큰글자도서) (89세 현역 트레이더 시게루 할아버지의 흔들리지 않는 투자 철학)',
#   'author': '후지모토 시게루',
#   'discount': '32010',
#   'publisher': '다산북스'},
#  {'title': '한국 주식 시장, 대세 상승기가 온다 (흔들려도 잃지 않는 주식 투자 전략)',
#   'author': '김태영',
#   'discount': '18720',
#   'publisher': '두드림미디어'},
#  {'title': '수민이의 미국 주식 투자 스토리 (미국 주식 투자의 대가가 들려주는  짧지만 강력한 투자의 지혜)',
#   'author': '이주택',
#   'discount': '16200',
#   'publisher': '월요일의 꿈'},
#  {'title': '주식 투자 뉴메릭 이론 #32. Time Addition Drop',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '알트코인 실전 투자 바이블 (압도적 수익을 현실로 만드는)',
#   'author': '박종한',
#   'discount': '22500',
#   'publisher': '헤리티지북스'},
#  {'title': '주식 투자 뉴메릭 이론 #31 Time Addition Rally',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '손실 없는 투자 원칙 (대한민국 최상위 슈퍼개미의 저점매수 고점매도)',
#   'author': '남석관',
#   'discount': '5400',
#   'publisher': '모루'},
#  {'title': '주린이도 술술 읽는 친절한 금융책 (주식 초보자를 위한 최소한의 금융 공부)',
#   'author': '최정희',
#   'discount': '17100',
#   'publisher': '메이트북스'},
#  {'title': '월 300만 원 버는 주식 투자 공식(큰글자도서) (미국 ETF 투자로 평생 월급 받는 법)',
#   'author': '진서빈',
#   'discount': '40000',
#   'publisher': '이든하우스'},
#  {'title': '종목탐색기 활용, 주식 투자로 100억 원 벌기 (검색기 활용하기)',
#   'author': '최익수',
#   'discount': '24300',
#   'publisher': '두드림미디어'},
#  {'title': '허영만의 주식 타짜 : 단타의 고수 한봉호·설산',
#   'author': '허영만',
#   'discount': '15120',
#   'publisher': '가디언'},
#  {'title': '업계지도 (AI가 바꾼 산업의 투자 지형도)',
#   'author': '한국비즈니스정보',
#   'discount': '25200',
#   'publisher': '어바웃어북'},
#  {'title': '채권을 알면 주식이 보인다 (채권쟁이의 주식 투자법)',
#   'author': '신년기',
#   'discount': '18000',
#   'publisher': '아라크네'},
#  {'title': '주식 투자 뉴메릭 이론 #30 Energy Balance',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '외워서 바로 써먹는 단타 공식 (투자 수익 올려줄 지금 당장 사용 가능한 실전 테크닉)',
#   'author': '이창원',
#   'discount': '17100',
#   'publisher': '매일경제신문사'},
#  {'title': '버팀에서 원칙으로 (암호화폐 폭락장에서 버팀이 만든 투자 철학)',
#   'author': '김환일',
#   'discount': '16200',
#   'publisher': '좋은땅'},
#  {'title': '주식 매매 전략 (캔들 패턴 속 숨은 메시지를 읽는 기술)',
#   'author': '엄승민',
#   'discount': '56900',
#   'publisher': '부크크(bookk)'},
#  {'title': '나만의 미국주식 투자 필살기',
#   'author': '김영종',
#   'discount': '25200',
#   'publisher': '원앤원북스'},
#  {'title': '유목민의 투자의 정석',
#   'author': '유목민',
#   'discount': '25200',
#   'publisher': '리더스북'},
#  {'title': '주식 투자 뉴메릭 이론 #28 파이(Φ) projection',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '주식이 오르고 내리는 이유 (모든 투자자들에게 필요한 투자의 기본 지식들)',
#   'author': '빌 파이크^패트릭 그레고리',
#   'discount': '35100',
#   'publisher': '비지니스101'},
#  {'title': 'K-증시혁명 (한국증시, 2025년 이전과 이후로 나뉜다)',
#   'author': '강관우',
#   'discount': '18900',
#   'publisher': '뿌브아르'},
#  {'title': '주식 투자 뉴메릭 이론 #27 Time Energy Resist',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '성공적인 개인 투자를 위한 ETF 안내서',
#   'author': '안해성',
#   'discount': '17820',
#   'publisher': '지음미디어'},
#  {'title': '최저점 바닥 매매 비법(큰글자도서) (초보자 및 직장인을 위한 비법 공개)',
#   'author': '전원',
#   'discount': '35100',
#   'publisher': '시대인'},
#  {'title': '진짜 하루만에 이해하는 제약·바이오 산업 (강하나 전 애널리스트가 알려주는 제약·바이오 투자의 정석)',
#   'author': '강하나',
#   'discount': '22320',
#   'publisher': '티더블유아이지'},
#  {'title': '주식 투자 뉴메릭 이론 #26. Time Energy Support',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': 'ETF로 부사관 역량 강화',
#   'author': '황대건',
#   'discount': '17100',
#   'publisher': '드림벙커'},
#  {'title': '주식 투자 뉴메릭 이론 #25 Time Energy Drop',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '배당투자 기적의 루틴 (지금 배당투자 50만 원으로 평생 월급 500만 원을 만드는)',
#   'author': '곽병열',
#   'discount': '19800',
#   'publisher': '한스미디어'},
#  {'title': '주식 투자 뉴메릭 이론 #23. √7=2.646',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '1년에 1천만 원 수익 내는 주식 투자 기술 (작고 소중한 월급을 모으고 불리는 기적의 솔루션)',
#   'author': '인디플랜(안형준)',
#   'discount': '18000',
#   'publisher': '원앤원북스'},
#  {'title': '주식 투자 뉴메릭 이론 #24 Time Energy Rally',
#   'author': '손태건(타이쿤)',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '처음부터 배우는 투자 심리학 (일 잘하는 사람들의 비밀 노트 08)',
#   'author': '백광석',
#   'discount': '15300',
#   'publisher': '다온길'},
#  {'title': '주린이의 주식 심리 생존 전략',
#   'author': '윤창섭',
#   'discount': '19300',
#   'publisher': '부크크(bookk)'},
#  {'title': '주식 투자 뉴메릭 이론 #22 √5=2.236',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': 'ETF 투자 무작정 따라하기 (손쉽게 투자해서 확실히 수익 내는 ETF의 모든 것)',
#   'author': '윤재수',
#   'discount': '19800',
#   'publisher': '길벗'},
#  {'title': '투자의 시간 (현명한 투자자가 되기 위한)',
#   'author': '권오상',
#   'discount': '18000',
#   'publisher': '지베르니'},
#  {'title': 'AI가 골라 담는 ETF (95개 가상사례로 읽는 AI 기반 ETF 투자 전략)',
#   'author': '원제무',
#   'discount': '21160',
#   'publisher': '피앤씨미디어'},
#  {'title': '주식 투자 뉴메릭 이론 #20 √2=1.4142',
#   'author': '손태건(타이쿤)',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '주식 투자 뉴메릭 이론 #21. √3=1.732',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': 'Private Equity: 사서, 키워서, 팔아라 (기업을 지배하는 자본, 사례로 읽는 그들의 투자)',
#   'author': '윤민서',
#   'discount': '17820',
#   'publisher': '바른북스'},
#  {'title': '주식 투자 뉴메릭 이론 #19 파이(Φ) 원리',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '주식 투자 뉴메릭 이론 #18 Ratio Projection',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '마라톤 투자자 서한 (’자본사이클’을 활용한 주식투자 성공 전략!)',
#   'author': '에드워드 챈슬러',
#   'discount': '26550',
#   'publisher': '부크온'},
#  {'title': '돈에 대해 생각하고 또 생각하라 (코스톨라니와의 인터뷰: 투자와 통찰력)',
#   'author': '앙드레 코스톨라니^요하네스 그로스',
#   'discount': '15300',
#   'publisher': '이레미디어'},
#  {'title': '주식 투자 뉴메릭 이론 #17 Three Stage Movement',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '주식 투자 뉴메릭 이론 #16 Time Sum',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '거래량 투자 기법 (거래량과 가격의 비밀을 밝힌다!)',
#   'author': '애나 쿨링',
#   'discount': '20700',
#   'publisher': '이레미디어'},
#  {'title': '볼린저 밴드 트레이딩 (추세와 목표치를 보면서 거래하는 방법)',
#   'author': '손태건',
#   'discount': '16490',
#   'publisher': '부크크(bookk)'},
#  {'title': '주식 투자 뉴메릭 이론 #15 Time Projection',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '주식 투자 뉴메릭 이론 #14 Time Energy Projection',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '주식 투자 뉴메릭 이론 #12 Trend Ratio, Impulse Ratio',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '주식 투자 뉴메릭 이론 #13 Time Intensity Ratio',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '주식 투자 뉴메릭 이론 #10 Double Time Rule',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '주식 투자 뉴메릭 이론 #11 Prime Ratio = F2.618',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '차트 분석 바이블 (치과아저씨의 투자 스케일링과 함께하는)',
#   'author': '치과아저씨(팀 연세덴트)',
#   'discount': '45000',
#   'publisher': '한스미디어'},
#  {'title': '이순신의 학익진 주식 투자법',
#   'author': '김한주',
#   'discount': '19800',
#   'publisher': '북쿡'},
#  {'title': '인공지능, 주식분석 좀 부탁해 (입문자를 위한 파이썬 주식분석 프로그램 만들기)',
#   'author': '곽경일',
#   'discount': '21600',
#   'publisher': '비제이퍼블릭'},
#  {'title': '주식 투자 뉴메릭 이론 #9 Time Energy Symmetry',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '주식 투자 원리 뉴메릭 이론 #8 Time Multiple',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '주식투자의 첫걸음은 기업분석부터 (돈버는 투자를 위한 기업분석 6단계)',
#   'author': '변지희',
#   'discount': '20700',
#   'publisher': '새로운제안'},
#  {'title': '주식 투자 원리 뉴메릭 이론 #7 IA파동(아이에이)파동',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '주식 투자 원리 뉴메릭 이론 #6 VI(브이아이)파동',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '찰리 멍거 바이블 (현인들의 현자 멍거가 알려주는 투자와 삶의 지혜)',
#   'author': '김재현^이건',
#   'discount': '22500',
#   'publisher': '에프엔미디어'},
#  {'title': '투자의 정도 (주식 투자 이론편)',
#   'author': 'Trader Pack',
#   'discount': '16200',
#   'publisher': '북랩'},
#  {'title': '주식 투자의 모든 것 (시장을 이기는 277가지 전략과 통찰)',
#   'author': '엄승민',
#   'discount': '70000',
#   'publisher': '부크크(bookk)'},
#  {'title': '주식 투자 원리 뉴메릭 이론 #5 IV(아이브이)파동',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '직업군인 주식 투자 이야기 (책 100권 읽고 성공한)',
#   'author': '황상우',
#   'discount': '17100',
#   'publisher': '드림벙커'},
#  {'title': '해외선물투자의 이해 차트에 살자',
#   'author': '박용화^양창수',
#   'discount': '22500',
#   'publisher': '서울경제경영출판사'},
#  {'title': '주식 투자 원리 뉴메릭 이론 #3 Range & Base',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '주식 투자 원리 뉴메릭 이론 #4 AI(에이아이)파동',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '사모펀드 투자와 경영의 비밀',
#   'author': '김태엽',
#   'discount': '24300',
#   'publisher': '세이코리아'},
#  {'title': '주식 투자 뉴메릭 이론 #2. Twin Sum, Triple Sum',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': '평생 투자자 (일본 주식시장의 판을 흔들어 깨운 담대한 도전들)',
#   'author': '무라카미 요시아키',
#   'discount': '19800',
#   'publisher': '에프엔미디어'},
#  {'title': '어떻게 빅테크가 되는가 (미래 주식시장의 게임체인저)',
#   'author': '오재화',
#   'discount': '19800',
#   'publisher': '새빛'},
#  {'title': '한국형 모멘텀 투자 실전 매매법',
#   'author': '이가근',
#   'discount': '21600',
#   'publisher': '메이트북스'},
#  {'title': '지금 시작하는 초보자가 미국 주식으로 수익 내는 49가지 방법 (꼭 필요한 지식만으로 꽉 채운 가장 쉽고 실용적인 미국 주식 투자 입문서)',
#   'author': '김호균',
#   'discount': '22500',
#   'publisher': '한스미디어'},
#  {'title': '빅테크와 AI 그리고 투자전쟁',
#   'author': '류충석',
#   'discount': '32300',
#   'publisher': '부크크(bookk)'},
#  {'title': '버핏2배랩의 천장 바닥 매매 비법 (시점을 포착하는 사이클 투자 전략)',
#   'author': '한스(장환철)',
#   'discount': '21420',
#   'publisher': '베가북스'},
#  {'title': '현명한 투자자: 해제 (한국 주식시장에서도 증명된 벤저민 그레이엄 이론)',
#   'author': '신진오',
#   'discount': '18000',
#   'publisher': '국일증권경제연구소'},
#  {'title': '주식 투자 뉴메릭 이론 #1. 피보나치 삼각형',
#   'author': '손태건',
#   'discount': '16000',
#   'publisher': '부크크(bookk)'},
#  {'title': 'cis의 주식 투자 법칙 (주식으로 2300억을 번 일본 단타의 신)',
#   'author': 'cis',
#   'discount': '16650',
#   'publisher': '이레미디어'},
#  {'title': '첨성대에서 월스트리트 그리고 여의도 (증권시장의 국제화를 체험한 펀드매니저가 전하는 외국인이 바라본 국내 주식시장)',
#   'author': '이장호',
#   'discount': '15120',
#   'publisher': '바른북스'},
#  {'title': '주식이 말해주지 못한 소소한 이야기들',
#   'author': '김종안',
#   'discount': '13500',
#   'publisher': '생각나눔'},
#  {'title': '돌파매매 전략 (전미투자대회 우승자들의 핵심 매매 기법)',
#   'author': 'systrader79^김대현',
#   'discount': '22500',
#   'publisher': '이레미디어'},
#  {'title': '허영만의 주식 타짜 : 가치 평가의 대가 백지윤·김철광 (가치 평가의 대가 백지윤·김철광)',
#   'author': '허영만',
#   'discount': '15120',
#   'publisher': '가디언'},
#  {'title': '노마드 투자자 서한 (투자업계의 전설 ‘노마드 투자조합’의 시간을 자본으로 바꾸는 장기 퀄리티 투자 원칙과 지혜)',
#   'author': '닉 슬립',
#   'discount': '0',
#   'publisher': '더퀘스트'},
#  {'title': '차트의 언어를 해독하라 (캔들스틱부터 윅오프까지의 완전 정복)',
#   'author': '엄승민',
#   'discount': '20661',
#   'publisher': '부크크(bookk)'},
#  {'title': '돈 되는 주식테마 완전공략',
#   'author': '황용(Daniel Hwang)',
#   'discount': '19400',
#   'publisher': '부크크(bookk)'},
#  {'title': '스테이 더 코스 (존 보글의 흔들림 없는 투자)',
#   'author': '존 보글',
#   'discount': '29700',
#   'publisher': '이콘'},
#  {'title': '부를 창조한 주식 투자 거장들 (77가지 성공 방법론)',
#   'author': '엄승민',
#   'discount': '31600',
#   'publisher': '부크크(bookk)'},
#  {'title': '나는 배당투자로 매일 스타벅스 커피를 공짜로 마신다 (평생 월 500만 원씩 버는 30일 기적의 배당 파이프라인 공략집)',
#   'author': '송민섭(수페TV)',
#   'discount': '21600',
#   'publisher': '21세기북스'},
#  {'title': '차트보다 먼저 알아야 할 주식 언어',
#   'author': '엄승민',
#   'discount': '77500',
#   'publisher': '부크크(bookk)'},
#  {'title': '분석하는 개미',
#   'author': '엄승민',
#   'discount': '78100',
#   'publisher': '부크크(bookk)'},
#  {'title': '세상에서 제일 쉬운 주가 차트 실전 노트: 데이 트레이딩 편 (데이 트레이딩 편)',
#   'author': '사가라 후미아키',
#   'discount': '17820',
#   'publisher': '두드림미디어'},
#  {'title': '실전 퀀트투자(리커버판) (수익률을 확인하고 투자하라)',
#   'author': '홍용찬',
#   'discount': '18900',
#   'publisher': '이레미디어'},
#  {'title': '한국형 주식 매매법 (살 자리 팔 자리 잡아주는)',
#   'author': '이성웅^이주현',
#   'discount': '19800',
#   'publisher': '지식노마드'},
#  {'title': '주린이가 가장 알고 싶은 최다질문 TOP 77 2 (’염블리’염승환과 함께라면 주식이 쉽고 재미있다)',
#   'author': '염승환',
#   'discount': '17100',
#   'publisher': '메이트북스'},
#  {'title': '2025-2027 앞으로 3년 미국 주식 트렌드 (미래를 지배할 미국 산업 트렌드와 반드시 주목해야 할 기업 37)',
#   'author': '최중혁^스파클링 투자클럽',
#   'discount': '22500',
#   'publisher': '한스미디어'},
#  {'title': '주가 모멘텀이란 무엇인가? (주가 에너지를 측정하는 4가지 방법)',
#   'author': '손태건',
#   'discount': '26000',
#   'publisher': '부크크(bookk)'},
#  {'title': '워런 버핏 투자 노트 (투자의 신에게 배우는 삶의 지혜와 투자의 기술!)',
#   'author': '서희경 옮김, 하마모토 아키라 감수',
#   'discount': '12600',
#   'publisher': '소보랩'}]

# %%
book_collection = db.books

book_collection.insert_many(books_mongo)
# Out:
# InsertManyResult([ObjectId('698d8c1e0c2804303c9865d8'), ObjectId('698d8c1e0c2804303c9865d9'), ObjectId('698d8c1e0c2804303c9865da'), ObjectId('698d8c1e0c2804303c9865db'), ObjectId('698d8c1e0c2804303c9865dc'), ObjectId('698d8c1e0c2804303c9865dd'), ObjectId('698d8c1e0c2804303c9865de'), ObjectId('698d8c1e0c2804303c9865df'), ObjectId('698d8c1e0c2804303c9865e0'), ObjectId('698d8c1e0c2804303c9865e1'), ObjectId('698d8c1e0c2804303c9865e2'), ObjectId('698d8c1e0c2804303c9865e3'), ObjectId('698d8c1e0c2804303c9865e4'), ObjectId('698d8c1e0c2804303c9865e5'), ObjectId('698d8c1e0c2804303c9865e6'), ObjectId('698d8c1e0c2804303c9865e7'), ObjectId('698d8c1e0c2804303c9865e8'), ObjectId('698d8c1e0c2804303c9865e9'), ObjectId('698d8c1e0c2804303c9865ea'), ObjectId('698d8c1e0c2804303c9865eb'), ObjectId('698d8c1e0c2804303c9865ec'), ObjectId('698d8c1e0c2804303c9865ed'), ObjectId('698d8c1e0c2804303c9865ee'), ObjectId('698d8c1e0c2804303c9865ef'), ObjectId('698d8c1e0c2804303c9865f0'), ObjectId('698d8c1e0c2804303c9865f1'), ObjectId('698d8c1e0c2804303c9865f2'), ObjectId('698d8c1e0c2804303c9865f3'), ObjectId('698d8c1e0c2804303c9865f4'), ObjectId('698d8c1e0c2804303c9865f5'), ObjectId('698d8c1e0c2804303c9865f6'), ObjectId('698d8c1e0c2804303c9865f7'), ObjectId('698d8c1e0c2804303c9865f8'), ObjectId('698d8c1e0c2804303c9865f9'), ObjectId('698d8c1e0c2804303c9865fa'), ObjectId('698d8c1e0c2804303c9865fb'), ObjectId('698d8c1e0c2804303c9865fc'), ObjectId('698d8c1e0c2804303c9865fd'), ObjectId('698d8c1e0c2804303c9865fe'), ObjectId('698d8c1e0c2804303c9865ff'), ObjectId('698d8c1e0c2804303c986600'), ObjectId('698d8c1e0c2804303c986601'), ObjectId('698d8c1e0c2804303c986602'), ObjectId('698d8c1e0c2804303c986603'), ObjectId('698d8c1e0c2804303c986604'), ObjectId('698d8c1e0c2804303c986605'), ObjectId('698d8c1e0c2804303c986606'), ObjectId('698d8c1e0c2804303c986607'), ObjectId('698d8c1e0c2804303c986608'), ObjectId('698d8c1e0c2804303c986609'), ObjectId('698d8c1e0c2804303c98660a'), ObjectId('698d8c1e0c2804303c98660b'), ObjectId('698d8c1e0c2804303c98660c'), ObjectId('698d8c1e0c2804303c98660d'), ObjectId('698d8c1e0c2804303c98660e'), ObjectId('698d8c1e0c2804303c98660f'), ObjectId('698d8c1e0c2804303c986610'), ObjectId('698d8c1e0c2804303c986611'), ObjectId('698d8c1e0c2804303c986612'), ObjectId('698d8c1e0c2804303c986613'), ObjectId('698d8c1e0c2804303c986614'), ObjectId('698d8c1e0c2804303c986615'), ObjectId('698d8c1e0c2804303c986616'), ObjectId('698d8c1e0c2804303c986617'), ObjectId('698d8c1e0c2804303c986618'), ObjectId('698d8c1e0c2804303c986619'), ObjectId('698d8c1e0c2804303c98661a'), ObjectId('698d8c1e0c2804303c98661b'), ObjectId('698d8c1e0c2804303c98661c'), ObjectId('698d8c1e0c2804303c98661d'), ObjectId('698d8c1e0c2804303c98661e'), ObjectId('698d8c1e0c2804303c98661f'), ObjectId('698d8c1e0c2804303c986620'), ObjectId('698d8c1e0c2804303c986621'), ObjectId('698d8c1e0c2804303c986622'), ObjectId('698d8c1e0c2804303c986623'), ObjectId('698d8c1e0c2804303c986624'), ObjectId('698d8c1e0c2804303c986625'), ObjectId('698d8c1e0c2804303c986626'), ObjectId('698d8c1e0c2804303c986627'), ObjectId('698d8c1e0c2804303c986628'), ObjectId('698d8c1e0c2804303c986629'), ObjectId('698d8c1e0c2804303c98662a'), ObjectId('698d8c1e0c2804303c98662b'), ObjectId('698d8c1e0c2804303c98662c'), ObjectId('698d8c1e0c2804303c98662d'), ObjectId('698d8c1e0c2804303c98662e'), ObjectId('698d8c1e0c2804303c98662f'), ObjectId('698d8c1e0c2804303c986630'), ObjectId('698d8c1e0c2804303c986631'), ObjectId('698d8c1e0c2804303c986632'), ObjectId('698d8c1e0c2804303c986633'), ObjectId('698d8c1e0c2804303c986634'), ObjectId('698d8c1e0c2804303c986635'), ObjectId('698d8c1e0c2804303c986636'), ObjectId('698d8c1e0c2804303c986637'), ObjectId('698d8c1e0c2804303c986638'), ObjectId('698d8c1e0c2804303c986639'), ObjectId('698d8c1e0c2804303c98663a'), ObjectId('698d8c1e0c2804303c98663b'), ObjectId('698d8c1e0c2804303c98663c'), ObjectId('698d8c1e0c2804303c98663d'), ObjectId('698d8c1e0c2804303c98663e'), ObjectId('698d8c1e0c2804303c98663f'), ObjectId('698d8c1e0c2804303c98 ...
